# %%
import numpy as np
import pandas as pd
from scipy.stats import linregress
import warnings
warnings.filterwarnings('ignore')

# %%
sales12 = pd.read_csv("Calculation Data/countysales12.csv")
sales13 = pd.read_csv("Calculation Data/countysales13.csv")
sales14 = pd.read_csv("Calculation Data/countysales14.csv")
sales15 = pd.read_csv("Calculation Data/countysales15.csv")
sales16 = pd.read_csv("Calculation Data/countysales16.csv")
sales17 = pd.read_csv("Calculation Data/countysales17.csv")

# %%
locations12 = pd.read_csv("Calculation Data/zipcodelocation12.csv")
locations13 = pd.read_csv("Calculation Data/zipcodelocation13.csv")
locations14 = pd.read_csv("Calculation Data/zipcodelocation14.csv")
locations15 = pd.read_csv("Calculation Data/zipcodelocation15.csv")
locations16 = pd.read_csv("Calculation Data/zipcodelocation16.csv")
locations17 = pd.read_csv("Calculation Data/zipcodelocation17.csv")
del locations12["Unnamed: 0"]
del locations12["State"]
del locations12["Status"]
del locations13["Unnamed: 0"]
del locations13["State"]
del locations13["Status"]
del locations14["Unnamed: 0"]
del locations14["State"]
del locations14["Status"]
del locations15["Unnamed: 0"]
del locations15["State"]
del locations15["Status"]
del locations16["Unnamed: 0"]
del locations16["State"]
del locations16["Status"]
del locations17["Unnamed: 0"]
del locations17["State"]
del locations17["Status"]

# %%
sales12.sort_values(by='Total Poverty Rate (%)', ascending=False).head(5)
sales14.sort_values(by='Sale (Dollars)', ascending=False).head(5)
# Out:
#     Unnamed: 0      County  Date  Sale (Dollars)  Volume Sold (Gallons)  \
# 76          76        Polk  2014     59476777.54             1034448.63
# 56          56        Linn  2014     23575832.62              446002.72
# 81          81       Scott  2014     19538877.03              343795.87
# 51          51     Johnson  2014     16657159.53              282883.75
# 6            6  Black Hawk  2014     15833551.46              288527.84
#
#     Population  Poverty Count  Total Poverty Rate (%)
# 76    445136.0        54642.0               12.275350
# 56    214927.0        20005.0                9.307811
# 81    168714.0        21155.0               12.538971
# 51    136802.0        22733.0               16.617447
# 6     131947.0        20919.0               15.854093

# %%
sales12.describe()
# Out:
#        Unnamed: 0    Date  Sale (Dollars)  Volume Sold (Gallons)  \
# count   99.000000    99.0    9.900000e+01              99.000000
# mean    49.000000  2012.0    2.575236e+06           49987.971566
# std     28.722813     0.0    6.527921e+06          119150.919136
# min      0.000000  2012.0    1.879359e+04             360.925067
# 25%     24.500000  2012.0    4.236830e+05            9217.220000
# 50%     49.000000  2012.0    7.856474e+05           17362.720000
# 75%     73.500000  2012.0    1.677797e+06           34846.110000
# max     98.000000  2012.0    5.519011e+07          995284.220000
#
#           Population  Poverty Count  Total Poverty Rate (%)
# count      99.000000      99.000000               99.000000
# mean    30784.303030    3643.131313               11.403151
# std     53025.357141    6371.033756                2.961462
# min      4027.000000     445.000000                5.142307
# 25%     10393.500000    1071.500000                9.279461
# ...

# %%
sales13.sort_values(by='Total Poverty Rate (%)', ascending=False).head(5).sum()
sales13.sort_values(by='Sale (Dollars)', ascending=False).head(5)
# Out:
#     Unnamed: 0      County  Date  Sale (Dollars)  Volume Sold (Gallons)  \
# 76          76        Polk  2013     56057048.32              990043.91
# 56          56        Linn  2013     23224587.71              440499.61
# 81          81       Scott  2013     18384930.01              331797.19
# 51          51     Johnson  2013     15266328.93              263749.65
# 6            6  Black Hawk  2013     15107130.74              277660.05
#
#     Population  Poverty Count  Total Poverty Rate (%)
# 76    438307.0        50853.0               11.602142
# 56    213425.0        20222.0                9.474991
# 81    167080.0        21446.0               12.835767
# 51    134034.0        22300.0               16.637570
# 6     131468.0        21308.0               16.207746

# %%
sales13.describe()
# Out:
#        Unnamed: 0    Date  Sale (Dollars)  Volume Sold (Gallons)  \
# count   99.000000    99.0    9.900000e+
sort_values(by='Total Poverty Rate (%)', ascending=False).head(5)
sales16.sort_values(by='Sale (Dollars)', ascending=False).head(5)
# Out:
#     Unnamed: 0      County  Date  Sale (Dollars)  Volume Sold (Gallons)  \
# 76          76        Polk  2016     65849028.78             1089776.96
# 56          56        Linn  2016     25044781.44              455061.20
# 81          81       Scott  2016     20649645.24              349170.29
# 51          51     Johnson  2016     17425355.41              290109.63
# 6            6  Black Hawk  2016     16597788.07              291648.51
#
#     Population  Poverty Count  Total Poverty Rate (%)
# 76    459159.0        55972.0               12.190113
# 56    218076.0        19912.0                9.130762
# 81    171116.0        20413.0               11.929334
# 51    142006.0        23911.0               16.838021
# 6     132821.0        19605.0               14.760467

# %%
sales16.describe()
# Out:
#        Unnamed: 0    Date  Sale (Dollars)  Volume Sold (Gallons)  \
# count   99.000000    99.0    9.900000e+01           9.900000e+01
# mean    49.000000  2016.0    2.903180e+06           5.210695e+04
# std     28.722813     0.0    7.645268e+06           1.282774e+05
# min      0.000000  2016.0    2.802676e+04           5.248504e+02
# 25%     24.500000  2016.0    4.417059e+05           8.853065e+03
# 50%     49.000000  2016.0    8.747833e+05           1.771914e+04
# 75%     73.500000  2016.0    1.787389e+06           3.565835e+04
# max     98.000000  2016.0    6.584903e+07           1.089777e+06
#
#           Population  Poverty Count  Total Poverty Rate (%)
# count      99.000000      99.000000               99.000000
# mean    31379.686869    3735.636364               11.434985
# std     55973.638913    7025.620663                3.157966
# min      3822.000000     368.000000                5.666419
# 25%     10134.000000    1094.500000                9.280408
# ...

# %%
sales17.sort_values(by='Total Poverty Rate (%)', ascending=False).head(5)
sales17.sort_values(by='Sale (Dollars)', ascending=False).head(5)
# Out:
#     Unnamed: 0      County  Date  Sale (Dollars)  Volume Sold (Gallons)  \
# 76          76        Polk  2017     70524271.51             1135421.66
# 56          56        Linn  2017     27338206.25              487767.12
# 81          81       Scott  2017     22010148.84              366750.88
# 51          51     Johnson  2017     19301290.45              320315.29
# 6            6  Black Hawk  2017     17238824.27              295564.72
#
#     Population  Poverty Count  Total Poverty Rate (%)
# 76     14933.0         1344.0                9.000201
# 56     17711.0         1806.0               10.197053
# 81     36945.0         5539.0               14.992557
# 51     15393.0         1963.0               12.752550
# 6      80864.0         4345.0                5.373219

# %%
sales17.describe()
# Out:
#        Unnamed: 0    Date  Sale (Dollars)  Volume Sold (Gallons)  \
# count   99.000000    99.0    9.900000e+01           9.900000e+01
# mean    49.000000  2017.0    3.113603e+06           5.515688e+04
# std     28.722813     0.0    8.211540e+06           1.346344e+05
# min      0.000000  2017.0    4.898859e+04           1.023940e+03
# 25%     24.500000  2017.0    4.833982e+05           9.866930e+03
# 50%     49.000000  2017.0    9.530773e+05           1.842632e+04
# 75%     73.500000  2017.0    1.869988e+06           3.660893e+04
# max     98.000000  2017.0    7.052427e+07           1.135422e+06
#
#           Population  Poverty Count  Total Poverty Rate (%)
# count      99.000000      99.000000               99.000000
# mean    31495.979798    3649.929293               11.117124
# std     56784.999779    6866.154331                3.045563
# min      3785.000000     418.000000                4.819072
# 25%     10079.500000    1057.000000                9.125167
# ...
